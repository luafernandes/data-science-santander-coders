# %% [markdown]
# <div style="background-color: lightgreen; padding: 18px;">
#     <h1> Projeto| Estatística I
# </div>

# %% [markdown]
# ### Esse projeto visa a aplicação dos conceitos e ferramental da Estatística desenvolvidos nesse módulo

# %% [markdown]
# **Membros do grupo**
#
# - Fábio Duarte
# - Karina Ellen
# - Leonardo Vasconcelos
# - Lorena Bastos
# - Luciana Fernandas
# - Mateus Falcão
# - Philipe Vasconcelos

# %% [markdown]
# ###

# %%
import math
import pandas as pd
import numpy as np
import scipy.stats as stats
from matplotlib import pyplot as plt

# %% [markdown]
# ###
# ##### Para o desenvolvimento das atividades abaixo, o seu grupo pode escolher qualquer dataset que contenha uma coluna com valores inteiros.

# %%
df = pd.read_csv("athlete_events.csv")

# %%
df.head(10)
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
# 5   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
# 6   5  Christine Jacoba Aaftink   F  25.0   185.0    82.0     Netherlands
# 7   5  Christine Jacoba Aaftink   F  25.0   185.0    82.0     Netherlands
# 8   5  Christine Jacoba Aaftink   F  27.0   185.0    82.0     Netherlands
# 9   5  Christine Jacoba Aaftink   F  27.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season         City          Sport  \
# 0  CHN  1992 Summer  1992  Summer    Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer       London           Judo
# 2  DEN  1920 Summer  1920  Summer    Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer        Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter      Calgary  Speed Skating
# 5  NED  1988 Winter  1988  Winter      Calgary  Speed Skating
# 6  NED  1992 Winter  1992  Winter  Albertville  Speed Skating
# 7  NED  1992 Winter  1992  Winter  Albertville  Speed Skating
# 8  NED  1994 Winter  1994  Winter  Lillehammer  Speed Skating
# 9  NED  1994 Winter  1994  Winter  Lillehammer  Speed Skating
#
#                                 Event Medal
# 0         Basketball Men's Basketball   NaN
# 1        Judo Men's Extra-Lightweight   NaN
# 2             Football Men's Football   NaN
# 3         Tug-Of-War Men's Tug-Of-War  Gold
# 4    Speed Skating Women's 500 metres   NaN
# 5  Speed Skating Women's 1,000 metres   NaN
# 6    Speed Skating Women's 500 metres   NaN
# 7  Speed Skating Women's 1,000 metres   NaN
# 8    Speed Skating Women's 500 metres   NaN
# 9  Speed Skating Women's 1,000 metres   NaN

# %% [markdown]
# ###

# %% [markdown]
# __1) Em algum dataset, classifique as suas colunas em Quantitativa Discreta, Quantitiva Contínua, Qualitativa Ordinal ou Qualitativa Nominal.__

# %% [markdown]
# - **ID:** Qualitativa nominal
# - **Name:** Qualitativa nominal
# - **Sex:** Qualitativa nominal
# - **Age:** Quantitativa discreta
# - **Height:** Quantitativa contínua
# - **Weight:** Quantitativa contínua
# - **Team:** Qualitativa nominal
# - **NOC:** Qualitativa nominal
# - **Games:** Qualitativa ordinal
# - **Year:** Qualitativa ordinal
# - **Season:** Qualitativa ordinal
# - **City:** Qualitativa nominal
# - **Sport:** Qualitativa nominal
# - **Event:** Qualitativa nominal
# - **Medal:** Qualitativa ordinal

# %%
print("Variáveis qualitativas nominais")
display(df[["ID", "Name", "Sex", "Team", "NOC", "City", "Sport", "Event"]])
# Out:
# Variáveis qualitativas nominais
#             ID                      Name Sex            Team  NOC  \
# 0            1                 A Dijiang   M           China  CHN
# 1            2                  A Lamusi   M           China  CHN
# 2            3       Gunnar Nielsen Aaby   M         Denmark  DEN
# 3            4      Edgar Lindenau Aabye   M  Denmark/Sweden  DEN
# 4            5  Christine Jacoba Aaftink   F     Netherlands  NED
# ...        ...                       ...  ..             ...  ...
# 271111  135569                Andrzej ya   M        Poland-1  POL
# 271112  135570                  Piotr ya   M          Poland  POL
# 271113  135570                  Piotr ya   M          Poland  POL
# 271114  135571        Tomasz Ireneusz ya   M          Poland  POL
# 271115  135571        Tomasz Ireneusz ya   M          Poland  POL
#
#                   City          Sport  \
# 0            Barcelona     Basketball
# 1               London           Judo
# 2            Antwerpen       Football
# 3                Paris     Tug-Of-War
# 4              Calgary  Speed Skating
# ...                ...            ...
# 271111       Innsbruck           Luge
# 271112           Sochi    Ski Jumping
# 271113           Sochi    Ski Jumping
# 271114          Nagano      Bobsleigh
# 271115  Salt Lake City      Bobsleigh
#
#                                            Event
# 0                    Basketball Men's Basketball
# 1                   Judo Men's Extra-Lightweight
# 2                        Football Men's Football
# 3                    Tug-Of-War Men's Tug-Of-War
# 4               Speed Skating Women's 500 metres
# ...                                          ...
# 271111                Luge Mixed (Men)'s Doubles
# 271112  Ski Jumping Men's Large Hill, Individual
# 271113        Ski Jumping Men's Large Hill, Team
# 271114                      Bobsleigh Men's Four
# 271115                      Bobsleigh Men's Four
#
# [271116 rows x 8 columns]

# %%
print("Variáveis qualitativas ordinais")
display(df[["Games", "Year", "Season", "Medal"]])
# Out:
# Variáveis qualitativas ordinais
#               Games  Year  Season Medal
# 0       1992 Summer  1992  Summer   NaN
# 1       2012 Summer  2012  Summer   NaN
# 2       1920 Summer  1920  Summer   NaN
# 3       1900 Summer  1900  Summer  Gold
# 4       1988 Winter  1988  Winter   NaN
# ...             ...   ...     ...   ...
# 271111  1976 Winter  1976  Winter   NaN
# 271112  2014 Winter  2014  Winter   NaN
# 271113  2014 Winter  2014  Winter   NaN
# 271114  1998 Winter  1998  Winter   NaN
# 271115  2002 Winter  2002  Winter   NaN
#
# [271116 rows x 4 columns]

# %%
print("Variável quantitativa discreta")
display(df[["Age"]])
# Out:
# Variável quantitativa discreta
#          Age
# 0       24.0
# 1       23.0
# 2       24.0
# 3       34.0
# 4       21.0
# ...      ...
# 271111  29.0
# 271112  27.0
# 271113  27.0
# 271114  30.0
# 271115  34.0
#
# [271116 rows x 1 columns]

# %%
print("Variáveis quantitativas contínuas")
display(df[["Height", "Weight"]])
# Out:
# Variáveis quantitativas contínuas
#         Height  Weight
# 0        180.0    80.0
# 1        170.0    60.0
# 2          NaN     NaN
# 3          NaN     NaN
# 4        185.0    82.0
# ...        ...     ...
# 271111   179.0    89.0
# 271112   176.0    59.0
# 271113   176.0    59.0
# 271114   185.0    96.0
# 271115   185.0    96.0
#
# [271116 rows x 2 columns]

# %% [markdown]
# ###

# %% [markdown]
# __2) Com o mesmo dataset, construir a distribuição de probabilidade de uma feature com valores inteiros. Escrever uma função para calcular a Esperança e outra função para calcular a Variância dessa variável aleatória. Compare o resultado de sua função com os resultados de alguma nativa do Python (há muitos módulos/bibliotecas que calculam esses parâmetros). Construa uma função que faça o papel da cdf() e outra função com o papel da sf(). Desafio extra: construir funções que fazem o papel da ppf() e da isf() .__'.f'.

# %%
distribuicao_frequencias = df["Age"].value_counts().sort_index()

print("Distribuição de frequências")
display(distribuicao_frequencias)
# Out:
# Distribuição de frequências
# Age
# 10.0      1
# 11.0     13
# 12.0     39
# 13.0    187
# 14.0    837
#        ...
# 81.0      2
# 84.0      1
# 88.0      3
# 96.0      1
# 97.0      1
# Name: count, Length: 74, dtype: int64

# %%
distribuicao_probabilidades = distribuicao_frequencias / distribuicao_frequencias.sum()

print("Distribuição de probabilidades")
display(distribuicao_probabilidades)
# Out:
# Distribuição de probabilidades
# Age
# 10.0    0.000004
# 11.0    0.000050
# 12.0    0.000149
# 13.0    0.000715
# 14.0    0.003199
#           ...
# 81.0    0.000008
# 84.0    0.000004
# 88.0    0.000011
# 96.0    0.000004
# 97.0    0.000004
# Name: count, Length: 74, dtype: float64

# %%
plt.figure(figsize=(10,6))
plt.bar(distribuicao_probabilidades.index, distribuicao_probabilidades.values)

plt.title('Distribuição de probabilidades - Idades dos atletas olímpicos de 1896-2016', fontweight=1000, fontsize=14, y=1.05)
plt.xlabel('Idades')
plt.ylabel('Probabilidades')

plt.show()

# %%
X = distribuicao_probabilidades.index
p = distribuicao_probabilidades.values

# %%
def esperanca(X: list, p: list) -> float:
    """Esta função calcula a esperança dos dados.

    Parâmetros:
    - `X`: lista com os valores que a variável aleatória assume.
    - `p`: lista com as respectivas probabilidades dos dados de X.
    """
    return sum(xi * pi for xi, pi in zip(X, p))
 
def variancia(X: list, p: list) -> float:
    """Esta função calcula a variância dos dados.

    Parâmetros:
    - `X`: lista com os valores que a variável aleatória assume.
    - `p`: lista com as respectivas probabilidades dos dados de X.
    """
    return esperanca([xi ** 2 for xi in X], p) - esperanca(X, p) ** 2

esp = esperanca(X, p)
var = variancia(X, p)

# comparando resultados (funções esperança e variância x numpy)
print(f"""Comparando os resultados:

Esperança {round(esp, 2)} (Python)
Variância {round(var, 2)} (Python)

Esperança {np.round(np.dot(X, p), 2)} (NumPy)
Variância {np.round(np.dot(np.power(X, 2), p) - np.power(np.dot(X, p), 2), 2)} (NumPy)""")
# Out:
# Comparando os resultados:
#
# Esperança 25.56 (Python)
# Variância 40.88 (Python)
#
# Esperança 25.56 (NumPy)
# Variância 40.88 (NumPy)

# %%
# funções cdf, sf, ppf e isf
def cdf(X: list, p: list, xi: int) -> float:
    """Esta função calcula a soma de todas as probabilidades dos dados até um certo ponto.

    Parâmetros:
    - `X`: lista com os valores que a variável aleatória assume.
    - `p`: lista com as respectivas probabilidades dos dados de X.
    - `xi`: ponto limite para a soma das probabilidades.
    """
    acum = 0
    for i, el in enumerate(sorted(X)):
        if el <= xi:
            acum += p[i]
        else:
            break
    
    return acum

def sf(X: list, p: list, xi: int) -> float:
    """Esta função calcula a soma de todas as probabilidades dos dados a partir de um certo ponto.

    Parâmetros:
    - `X`: lista com os valores que a variável aleatória assume.
    - `p`: lista com as respectivas probabilidades dos dados de X.
    - `xi`: ponto inicial para a soma das probabilidades.
    """
    return 1 - cdf(X, p, xi)

def ppf(X: list, p: list, pi: float) -> float:
    """Esta função retorna um valor, dada a probabilidade acumulada do início até certo ponto.

    Parâmetros:
    - `X`: lista com os valores que a variável aleatória assume.
    - `p`: lista com as respectivas probabilidades dos dados de X.
    - `xi`: probabilidade acumulada até certo ponto.
    """
    z_proximo = 0
    acum = 0
    for i, el in enumerate(p):
        acum += el
        if acum <= pi:
            z_proximo = X[i]
        else:
            break

    return z_proximo

def isf(X: list, p: list, pi: float) -> float:
    """Esta função retorna um valor, dada a probabilidade acumulada a partir de um certo ponto até o fim.

    Parâmetros:
    - `X`: lista com os valores que a variável aleatória assume.
    - `p`: lista com as respectivas probabilidades dos dados de X.
    - `xi`: probabilidade acumulada de certo ponto até o fim.
    """
    return ppf(X, p, 1 - pi)

# comparando resultados (funções cdf, sf, ppf e isf x scipy)
print(f"""Comparando os resultados:

cdf {cdf(X, p, 25)} (Python)
sf {sf(X, p, 25)} (Python)
ppf {ppf(X, p, 0.5765167671856964)} (Python)
isf {isf(X, p, 0.42348323281430356)} (Python)

cdf {stats.rv_discrete(values=(X, p)).cdf(25)} (SciPy)
sf {stats.rv_discrete(values=(X, p)).sf(25)} (SciPy)
ppf {stats.rv_discrete(values=(X, p)).ppf(0.5765167671856964)} (SciPy)
isf {stats.rv_discrete(values=(X, p)).isf(0.42348323281430356)} (SciPy)""")
# Out:
# Comparando os resultados:
#
# cdf 0.5765167671856964 (Python)
# sf 0.42348323281430356 (Python)
# ppf 25.0 (Python)
# isf 25.0 (Python)
#
# cdf 0.5765167671856964 (SciPy)
# sf 0.42348323281430356 (SciPy)
# ppf 25.0 (SciPy)
# isf 25.0 (SciPy)

# %% [markdown]
# ###

# %% [markdown]
#  __3) Utilizando a variável aleatória do exercício anterior, construir a distribuição das médias amostrais para ilustrar/comprovar o Teorema do Limite Central. Comparar a média e a variância com o exercício anterior. Utilizar o teste de normalidade para verificar se essa distribuição (das médias amostrais) é normal ou  não.__

# %%
n = 500
n_amostras = 3000
amostra = [df["Age"].sample(n).reset_index(drop=True) for i in range(n_amostras)]
amostras = pd.concat(amostra, axis=1)
amostras.columns = [f"Amostra {(i + 1)}" for i in range(n_amostras)]

# %%
amostras
# Out:
#      Amostra 1  Amostra 2  Amostra 3  Amostra 4  Amostra 5  Amostra 6  \
# 0         33.0       25.0       28.0       27.0       28.0       22.0
# 1         33.0       28.0       27.0       31.0       22.0       19.0
# 2         28.0       26.0       29.0       24.0       21.0       20.0
# 3         38.0       35.0       17.0       28.0       24.0       26.0
# 4         19.0       17.0       22.0       22.0       19.0       22.0
# ..         ...        ...        ...        ...        ...        ...
# 495       24.0       39.0       22.0       27.0       24.0       22.0
# 496       33.0       23.0       26.0       19.0       26.0       32.0
# 497       35.0       23.0        NaN       18.0       18.0       66.0
# 498       29.0       24.0       24.0       17.0       20.0       31.0
# 499       26.0       27.0       18.0        NaN       26.0       24.0
#
#      Amostra 7  Amostra 8  Amostra 9  Amostra 10  ...  Amostra 2991  \
# 0         25.0       28.0       29.0        29.0  ...          25.0
# 1         28.0       41.0       26.0        30.0  ...          18.0
# 2         34.0       27.0       33.0        21.0  ...          27.0
# 3         25.0       40.0       28.0        29.0  ...          25.0
# 4         21.0       26.0       27.0        32.0  ...          22.0
# ..         ...        ...        ...         ...  ...           ...
# 495       16.0       24.0       25.0        46.0  ...          27.0
# 496       37.0       27.0       24.0        29.0  ...          16.0
# 497       34.0       29.0       24.0        19.0  ...           NaN
# 498       27.0       33.0       30.0        28.0  ...          43.0
# 499       16.0       31.0       23.0        27.0  ...          19.0
#
#      Amostra 2992  Amostra 2993  Amostra 2994  Amostra 2995  Amostra 2996  \
# 0            18.0          24.0          23.0          24.0          28.0
# 1            15.0          34.0          24.0          25.0          20.0
# 2            28.0          20.0          28.0          32.0          21.0
# 3            17.0          26.0          39.0          26.0           NaN
# 4            26.0          27.0          20.0          26.0          31.0
# ..            ...           ...           ...           ...           ...
# 495          21.0          46.0          35.0          31.0          21.0
# 496          26.0           NaN          26.0          34.0          23.0
# 497          27.0          21.0          24.0          24.0          26.0
# 498          24.0          19.0          68.0          25.0          19.0
# 499          19.0          23.0          26.0          20.0          29.0
#
#      Amostra 2997  Amostra 2998  Amostra 2999  Amostra 3000
# 0            30.0          22.0          22.0           NaN
# 1            21.0          30.0          27.0          24.0
# 2            32.0          29.0          25.0          27.0
# 3            32.0          33.0          22.0          21.0
# 4            22.0          35.0          28.0          28.0
# ..            ...           ...           ...           ...
# 495          27.0          28.0          24.0          19.0
# 496          23.0          28.0          33.0          18.0
# 497          26.0          27.0          22.0          48.0
# 498          18.0          15.0          33.0          34.0
# 499          29.0          23.0          36.0          29.0
#
# [500 rows x 3000 columns]

# %%
amostras.mean()
# Out:
# Amostra 1       25.740741
# Amostra 2       25.712810
# Amostra 3       25.648649
# Amostra 4       25.423554
# Amostra 5       25.407332
#                   ...
# Amostra 2996    25.492784
# Amostra 2997    25.538302
# Amostra 2998    25.803719
# Amostra 2999    25.673511
# Amostra 3000    25.300830
# Length: 3000, dtype: float64

# %%
plt.figure(figsize=(10,6)) 
plt.hist(amostras.mean(), bins=50, rwidth=0.8)

plt.title('Distribuição das médias amostrais das idades', fontweight=1000, fontsize=14, y=1.05)
plt.xlabel('Idades')
plt.ylabel('Contagem')

plt.show()

# %%
print(f"""Comparação da média e desvio padrão da população e amostras:

Média (esperança) da população: {esp}
Média das amostras: {amostras.mean().mean()}
Desvio padrão da população: {math.sqrt(var)}
Desvio padrão das amostras: {amostras.std().mean()}

Verificando a afirmação do Teorema do Limite Central:

Desvio padrão das médias amostrais: {amostras.mean().std()}
Desvio padrão populacional / Raiz quadrada do tamanho da amostra: {math.sqrt(var) / math.sqrt(n)}""")
# Out:
# Comparação da média e desvio padrão da população e amostras:
#
# Média (esperança) da população: 25.556898357297378
# Média das amostras: 25.558584801176345
# Desvio padrão da população: 6.393548628877127
# Desvio padrão das amostras: 6.381109936454661
#
# Verificando a afirmação do Teorema do Limite Central:
#
# Desvio padrão das médias amostrais: 0.29195718809190774
# Desvio padrão populacional / Raiz quadrada do tamanho da amostra: 0.28592818703239664

# %%
fig, ax = plt.subplots(figsize=(10, 6))

stats.probplot(df["Age"].sample(100), plot=ax)

plt.title('Teste de normalidade', fontweight=1000, fontsize=14, y=1.05)
plt.xlabel('Quantis teóricos')
plt.ylabel('Valores ordenados')

plt.show()

# %%
# por algum motivo a reta não aparece sempre,
# principalmente quando utilizamos uma maior quantidade de dados nas amostras

fig, ax = plt.subplots(figsize=(10, 6))

stats.probplot(df["Age"].sample(n), plot=ax)

plt.title('Teste de normalidade', fontweight=1000, fontsize=14, y=1.05)
plt.xlabel('Quantis teóricos')
plt.ylabel('Valores ordenados')

plt.show()

# %% [markdown]
# ###

# %% [markdown]
# __4) No exercício anterior, construir o intervalo de confiança para a média, com nível de confiança de 95% e erro percentual de 2% (para cima ou para baixo).__

# %%
desvio_padrao_populacional = math.sqrt(var)
desvio_padrao_medias_amostrais = amostras.mean().std()
media_amostral = amostras.mean().mean()
alpha = 0.05
Z = stats.norm.ppf(1 - alpha/2)
erro = 0.02
n = ((Z * desvio_padrao_medias_amostrais) / erro) ** 2

z_menos = (media_amostral - Z * (desvio_padrao_populacional / math.sqrt(n))) - (media_amostral * erro)
z_mais = (media_amostral + Z * (desvio_padrao_populacional / math.sqrt(n))) + (media_amostral * erro)

print("Intervalo de confiança:")
print(f'[{z_menos:.2f} , {z_mais:.2f}]') 

n
# Out:
# Intervalo de confiança:
# [24.61 , 26.51]
# 818.6052679556163

# %% [markdown]
# ###

# %% [markdown]
# __5) Se uma amostra de tamanho 30, vinda da variável aleatória do exercício 2), tiver uma média 10% maior que a média da população, a hipótese de que essas médias são iguais seria rejeitada ou não rejeitada, com um nível de confiança de 95%? (faça o teste de hipótese para responder essa pergunta).__

# %%
def testar_hipotese(atributo: pd.core.series.Series, amostra_tamanho: int, alpha: float, porcentagem_amostra: float) -> bool:
    media = np.mean(atributo)
    media_amostra = porcentagem_amostra * media
    
    std_amostra = np.std(atributo)
    
    intervalo_confianca = stats.norm.interval(alpha, loc=media_amostra, scale=std_amostra / np.sqrt(amostra_tamanho))
    z_crit = intervalo_confianca[1]
    
    Xc = media_amostra + (std_amostra / np.sqrt(amostra_tamanho)) * z_crit
    
    if media >= Xc:
        return False
    return True

# %%
testar_hipotese(df["Age"], n, 0.95, 1.1)
# Out:
# True
